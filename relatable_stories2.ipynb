# %% [markdown]
# ### define constants and compute timeseries

# %%
# declare starting wealth                                                                                                       
wealth_fund=0
wealth_etf=0

# decare annnual savings in millions
annual_deposit=0.03

# declare ETF annual return                                                                        
r_etf=1.07  # 7%/year
r_fund=1.04  # 4%/year

etf = []
fund = []

years = range(0, 30)
for t in years:
    fund.append(wealth_fund)
    wealth_bank += annual_deposit
    wealth_bank = wealth_bank * r_fund
    
    etf.append(wealth_etf)
    wealth_etf += annual_deposit
    wealth_etf = wealth_etf * r_etf
    
print(bank[-1])
print(etf[-1])
# Out:
# 0.8700000000000006
# 2.8038235897122994

# %% [markdown]
# ### plot the results

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
fig, ax = plt.subplots(figsize=(12, 8)) 

ax.plot(years, etf, 'b', linewidth=3, label='30K CHF/year deposit into ETF ({0}%/year)'.format(round((r_etf-1)*100)))
ax.plot(years, fund, 'r', linewidth=3, label='30K CHF/year cash deposit into bank')
plt.xlabel('Years after starting with 0CHF', fontsize=18)
plt.ylabel('Millions of CHF', fontsize=18)
ax.tick_params(axis='both', which='major', labelsize=14)
plt.legend(fontsize=16, loc='best')
plt.savefig('/Users/oliverangelil/Downloads/investment_returns/relatable_stories2.png', dpi=200)
plt.show()
